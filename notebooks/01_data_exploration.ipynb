# %%
import mne
import pandas as pd
import matplotlib.pyplot as plt

# %%
base_path = "/Users/sziwia/Documents/projekty health/seizure-risk-analysis/ds005873/sub-001/ses-01"
run = "07"

mov_path = f"{base_path}/mov/sub-001_ses-01_task-szMonitoring_run-{run}_mov.edf"
ecg_path = f"{base_path}/ecg/sub-001_ses-01_task-szMonitoring_run-{run}_ecg.edf"
events_path = f"{base_path}/eeg/sub-001_ses-01_task-szMonitoring_run-{run}_events.tsv"

raw_mov = mne.io.read_raw_edf(mov_path, preload=True, verbose=False)
raw_ecg = mne.io.read_raw_edf(ecg_path, preload=True, verbose=False)
events = pd.read_csv(events_path, sep='\t')

print(raw_mov.info)
print(events.head())
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG SD ACC X, EEG SD ACC Y, EEG SD ACC Z, EEG SD GYR A, EEG SD ...
#  chs: 12 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 12.5 Hz
#  meas_date: 2025-02-20 16:14:52 UTC
#  nchan: 12
#  projs: []
#  sfreq: 25.0 Hz
#  subject_info: <subject_info | his_id: X, sex: 0, last_name: X>
# >
#      onset  duration          eventType lateralization localization vigilance  \
# 0  16300.0     143.0  sz_foc_ia_m_tonic           left         temp     awake
#
#    confidence  channels             dateTime  recordingDuration
# 0         NaN       NaN  2000-01-01 00:00:00            29518.0
